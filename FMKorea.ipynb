# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlencode
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support import expected_conditions as EC
import time
from datetime import datetime as dtime
import csv
from lxml import etree

# %%
# 변수 설정
QUERY = "오세훈"
search_QUERY = urlencode({'query' : QUERY}, encoding = 'utf-8')
URL = f"https://www.fmkorea.com/search.php?mid=home&act=IS&where=&sph_sort=&search_target=&is_keyword=%EC%98%A4%EC%84%B8%ED%9B%88#gsc.sort=date&gsc.tab=&gsc.q=%EC%98%A4%EC%84%B8%ED%9B%88&" 
URL2 = 'https://www.fmkorea.com/search.php?mid=home&act=IS&is_keyword=%EC%98%A4%EC%84%B8%ED%9B%88&where=document&page='
PATH = 'C:/Users/jm215/Documents/MEGA/Crawlers/IMDB/chromedriver.exe'

# %%
# 마지막 페이지까지 클릭 
def go_to_last_page(URL): 
# Set up Chrome options for headless mode
	chrome_options = Options()
	chrome_options.add_argument("--headless")  # Run in headless mode
	chrome_options.add_argument("--disable-gpu")  # Disable GPU acceleration for headless mode

	# Specify the path to the chromedriver executable
	chromedriver_path = PATH


	service = webdriver.chrome.service.Service(executable_path= chromedriver_path)
	driver = webdriver.Chrome(service=service, options=chrome_options)
	'''
	#Linux
	options = webdriver.ChromeOptions()
	options.add_argument("--headless")
	driver = webdriver.Chrome(options=options, executable_path=ChromeDriverManager().install())
	'''
	# Set implicit wait time
	driver.implicitly_wait(1)

	# Navigate to the URL
	driver.get(URL)

	html = driver.page_source
	soup = BeautifulSoup(html, 'lxml')
	#driver.quit()
	return soup


# 마지막 페이지 번호 알아내기 
def get_last_page(URL): 
	soup = go_to_last_page(URL)
	#pagination = soup.find('div', {'class' : 'page'})
	pages = 999
	page_list = []
	#for page in pages[1 :]:
	#	page_list.append(int(page.get_text(strip=True)))
	max_page = 999
	print(f"총 {max_page} 개의 페이지가 있습니다.")
	return max_page

# %%
# 게시판 링크 모두 가져오기 
def get_boards(page_num):
    boards = []
    for index, page in enumerate(range(page_num)):
        if page == 0:
            continue
        if page >= 2 :
            break
        boards.append(URL2 + page)
        print(boards[-1])

    return boards

#max_page 원래는 page_num

# 게시글 링크 가져오기 
def get_posts(): 
    global QUERY
    global PAGES
    board_links = get_boards(PAGES)
    posts = []
    website = 'https://www.fmkorea.com'
    full_posts = []
    for board_link in board_links:
        chrome_options = Options()
        chrome_options.add_argument("--headless")  # Run in headless mode
        chrome_options.add_argument("--disable-gpu")  # Disable GPU acceleration for headless mode

        # Specify the path to the chromedriver executable
        chromedriver_path = PATH


        service = webdriver.chrome.service.Service(executable_path= chromedriver_path)
        driver = webdriver.Chrome(service=service, options=chrome_options)

        # Set implicit wait time
        driver.implicitly_wait(1)
        try:
            driver.get(board_link)
            links = driver.find_element(By.CLASS_NAME, 'searchResult')
            alist = links.find_elements(By.TAG_NAME, 'li')
            
            for link in alist:
                atag = link.find_element(By.TAG_NAME, 'a')
                text = atag.get_attribute('href')
                print(text)
                posts.append(text)

        except Exception as e:
            print(f"Error processing {board_link}: {e}")

        finally:
            driver.quit()
    
    print(f"총 {len(posts)} 개의 글 링크를 찾았습니다.")

    # 게시글 링크 csv로 저장 
    post_file = open(f"FMKOREA_{QUERY}_{PAGES}pages_inner_links.csv", mode='w', encoding='utf-8')
    writer = csv.writer(post_file)
    for post in posts:
        writer.writerow([website + post])
    post_file.close()
    
    return posts

# %%
# 한 페이지에서 정보 가져오기 
def extract_info(URL, wait_time=1, delay_time=1): 
	try:
		# Set up Chrome options for headless mode
		chrome_options = Options()
		chrome_options.add_argument("--headless")  # Run in headless mode
		chrome_options.add_argument("--disable-gpu")  # Disable GPU acceleration for headless mode

		chromedriver_path = PATH


		service = webdriver.chrome.service.Service(executable_path= chromedriver_path)
		driver = webdriver.Chrome(service=service, options=chrome_options)
		# Set implicit wait time
		driver.implicitly_wait(wait_time)

		# Navigate to the URL
		driver.get(URL)
		html = driver.page_source
		time.sleep(delay_time)

		soup = BeautifulSoup(html, 'lxml')
   
		title = soup.find('div', {'class' : 'top_area ngeb'}).find('h1', {'class' : 'np_18px'}).find('span', {'class' :'np_18px_span'}).get_text(strip=True)  #잘 찾아짐
		print('Title: ' , title)
		post_time = soup.find('div', {'class' : 'top_area ngeb'}).find('span', {'class' : 'date m_no'}).get_text(strip=True) #잘 찾아짐
		print('Time: ', post_time)
		post = soup.find('article').get_text(strip=True) 
		
		print('Post: ', post)

		reply_cnt = 1
		reply_content = ""
		replies = soup.find_all('div', {'class' : 'comment-content'})
		print(replies)
		
		for reply in replies:
			reply_content += reply.get_text(strip=True).replace('\n', '').replace('\r', '').replace('\t','') + "\n"
		print(reply_content)

		print(URL, "완료")

		return {'title' : title, 'post_time' :post_time, 'post' : post, 'reply_cnt' : reply_cnt, 'reply_content' : reply_content}
	except Exception as e:
		print(f"에러발생: {e}")
		print(URL, "에러")
		pass


def get_contents(): 
	global fmkorea_results
	post_links = get_posts()
	for post_link in post_links:
		content = extract_info(post_link)
		if content is not None:
			append_to_file(f"FMKOREA_{QUERY}_{PAGES} pages.csv", content)
		else:
			append_to_file(f"FMKOREA_{QUERY}_{PAGES} pages.csv", {'title' : '', 'post_time' : '', 'post' : '', 'replsy_count' : 0, 'reply_content' : ''})
	return print("모든 작업이 완료되었습니다.")

# %%
# 저장 파일 만드는 함수 
def save_to_file(): 
	global QUERY
	global PAGES
	file = open(f"fmkorea_{QUERY}_{PAGES} pages.csv", mode='w', encoding='utf-8')
	writer = csv.writer(file)
	#writer.writerow(['site', 'title', 'user_id', 'post_time', 'post', 'view_cnt', 'recomm_cnt', 'reply_cnt', 'reply_content'])
	writer.writerow(['title', 'post_time', 'post', 'reply_count','reply_content'])
	file.close()
	return file

# 파일 열어서 쓰는 함수 
def append_to_file(file_name, dictionary): 
	file = open(file_name, mode='a', encoding='utf-8') # 덮어 쓰기 
	writer = csv.writer(file)
	writer.writerow(list(dictionary.values()))
	file.close()
	return 


# 함수 실행 
PAGES = get_last_page(URL)
fmkorea_results = save_to_file()
get_contents()
# Out:
# 총 999 개의 페이지가 있습니다.
# https://www.fmkorea.com/search.php?mid=home&act=IS&is_keyword=%EC%98%A4%EC%84%B8%ED%9B%88&where=document&page=1
# https://www.fmkorea.com/6954018158
# https://www.fmkorea.com/6954001342
# https://www.fmkorea.com/6953994831
# https://www.fmkorea.com/6953828271
# https://www.fmkorea.com/6953569470
# https://www.fmkorea.com/6953350039
# https://www.fmkorea.com/6953036291
# https://www.fmkorea.com/6953005051
# https://www.fmkorea.com/6952756206
# https://www.fmkorea.com/6952724499
# 총 10 개의 글 링크를 찾았습니다.
# Title:  오세훈식 현황판 떳냐?
# Time:  2024.04.23 15:59
# Post:  어 이게 아닌가요?ㅋㅋ
# [<div class="comment-content"> <div class="comment_6954022891_6798786095 xe_content">100조나 쓰고 일자리씹창낸 ㅂㅅ</div> </div>, <div class="comment-content document_writer"> <div class="comment_6954024737_3407759003 xe_content"><a class="findParent" href="javascript:;" onclick="return findComment(6954022891);">추세추종롱충이</a> 훠훠 공공노인 일자리 늘렸습니다만</div> </div>]
# 100조나 쓰고 일자리씹창낸 ㅂㅅ
# 추세추종롱충이훠훠 공공노인 일자리 늘렸습니다만
#
# https://www.fmkorea.com/6954018158 완료
# Title:  오세훈 출생아 상황판 어떻게 보시나요?
# Time:  2024.04.23 15:54
# Post:  .
# [<div class="comment-content"> <div class="comment_6954002432_4989266336 xe_content">지가 대통령임? 서울 시정이나 똑바로 하지</div> </div>, <div class="comment-content"> <div class="comment_6954003931_6838793855 xe_content">나락</div> </div>, <div class="comment-content"> <div class="comment_6954004250_6827273898 xe_content">전형적인 보여주기식</div> </div>, <div class="comment-content"> <div class="comment_6954005516_4419834965 xe_content">군대에서 보던 무사고 몇일 이거 생각남</div> </div>, <div class="comment-content"> <div class="comment_6954005602_5282624921 xe_content">아 이분 민주당 영입인재셔?</div> </div>, <div class="comment-content"> <div class="comment_6954008856_3407759003 xe_content">옛날에 재앙이 일자리 상황판 같음</div> </div>, <div class="comment-content"> <div class="comment_6954009895_1148000596 xe_content">재앙이랑 원숭이가 하던거 따라함 ㅋㅋㅋㅋㅋ</div> </div>, <div class="comment-content"> <div class="comment_6954010212_4550984038 xe_content">성행위는 나쁜거라고 전기끊는다는 분</div> </div>, <div class="comment-content"> <div class="comment_6954012935_4886881034 xe_content">어디로 가야할지 모르면서 신호등만 쳐다보는 병신</div> </div>, <div class="comment-content"> <div class="comment_6954015389_44538285 xe_content">걍 박근혜 "살려야한다" 랑 똑같은거지</div> </div>, <div class="comment-content"> <div class="comment_6954021315_1567348179 xe_content">이거 사업 자체는 출산 직접지원이라 정책은 맞긴한데 ㅋㅋ 현황판은 너무 쇼질이다</div> </div>, <div class="comment-content"> <div class="comment_6954025134_6054538429 xe_content">전형적인 좌파식 최종결과값을 상황판 띄워놓으면 뭐함 <br/><br/>원인 파고 다녀야할 판에</div> </div>]
# 지가 대통령임? 서울 시정이나 똑바로 하지
# 나락
# 전형적인 보여주기식
# 군대에서 보던 무사고 몇일 이거 생각남
# 아 이분 민주당 영입인재셔?
# 옛날에 재앙이 일자리 상황판 같음
# 재앙이랑 원숭이가 하던거 따라함 ㅋㅋㅋㅋㅋ
# 성행위는 나쁜거라고 전기끊는다는 분
# 어디로 가야할지 모르면서 신호등만 쳐다보는 병신
# 걍 박근혜 "살려야한다" 랑 똑같은거지
# 이거 사업 자체는 출산 직접지원이라 정책은 맞긴한데 ㅋㅋ 현황판은 너무 쇼질이다
# 전형적인 좌파식 최종결과값을 상황판 띄워놓으면 뭐함원인 파고 다녀야할 판에
#
# https://www.fmkorea.com/6954001342 완료
# Title:  오세훈 존나 웃기네 미친년 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# Time:  2024.04.23 15:52
# Post:  남성의 성은 전기 끊는다 협박하고 죄악시 하면서출생아 상황판 쇼질은 니기미 개그하냐 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# [<div class="comment-content"> <div class="comment_6953996199_6827273898 xe_content">놈인데</div> </div>, <div class="comment-content"> <div class="comment_6953998864_1117575448 xe_content">그냥 원순이나 따라갔으면</div> </div>, <div class="comment-content"> <div class="comment_6953999063_6838793855 xe_content">오수윗</div> </div>, <div class="comment-content"> <div class="comment_6954012170_4385974468 xe_content">개그맨</div> </div>, <div class="comment-content"> <div class="comment_6954050408_3771668427 xe_content">오세훈이 죽으면 박원순이 마중나온다는 이야기가 있다. 나는 이 이야기를 참 좋아한다.</div> </div>, <div class="comment-content"> <div class="comment_6954053865_6319613083 xe_content">오 스윗 오</div> </div>, <div class="comment-content"> <div class="comment_6954055182_2082023747 xe_content">얘도 하는 짓이나 정책이 보수스럽지가 않음<br/>민주당이나 가지</div> </div>, <div class="comment-content"> <div class="comment_6954055772_3537742925 xe_content">세계에서 손꼽히는 거대도시 서울의 출산율은 한국의 출산율중에서도 바닥인데<br/><br/>서울시장이라는 새끼는 페미질에만 미쳐서 쇼나하고 있음 ㅋㅋㅋ</div> </div>, <div class="comment-content"> <div class="comment_6954061511_4923819110 xe_content">박원순이 만든 현황판 없애고 차별화했다고 언플하더니 자기가 똑같은거 만들고 있음<br/>여성지원에만 예산을 많이 쓰고 있고 <br/>대통령은 문재인 n년차에 서울시장은 박원순 n년차 같네 ㅋㅋㅋㅋㅋㅋ</div> </div>, <div class="comment-content"> <div class="comment_6954061831_3309254799 xe_content">남자의 본능은 죽이지만 여자들만 데리고 어떻게든 출산률은 올리고싶은ㅋㅋㅋㅋㅋㅋ</div> </div>, <div class="comment-content"> <div class="comment_6954076486_3249261315 xe_content">하나의 유령이 시청을 배회하고 있다. 원순씨라는 유령이</div> </div>, <div class="comment-content"> <div class="comment_6954117916_4239783990 xe_content">출산 상황판만들면 출산률 오르나<br/>그딴걸 왜한다는건지 ㅋㅋㅋㅋㅋㅋ</div> </div>, <div class="comment-content"> <div class="comment_6954126728_6756767027 xe_content">왜 아직도 박원순이 서울시장이지..</div> </div>, <div class="comment-content"> <div class="comment_6954155295_5204752970 xe_content">골고루 지랄염병하네</div> </div>]
# 놈인데
# 그냥 원순이나 따라갔으면
# 오수윗
# 개그맨
# 오세훈이 죽으면 박원순이 마중나온다는 이야기가 있다. 나는 이 이야기를 참 좋아한다.
# 오 스윗 오
# 얘도 하는 짓이나 정책이 보수스럽지가 않음민주당이나 가지
# 세계에서 손꼽히는 거대도시 서울의 출산율은 한국의 출산율중에서도 바닥인데서울시장이라는 새끼는 페미질에만 미쳐서 쇼나하고 있음 ㅋㅋㅋ
xe_content"><a class="findParent" href="javascript:;" onclick="return findComment(6953354106);">발레리안27</a> 지는 도박 전문이니 알등이 정치인이라 부르자</div> </div>, <div class="comment-content"> <div class="comment_6953357010_40309004 xe_content"><a class="findParent" href="javascript:;" onclick="return findComment(6953355529);">따다다동</a> 🍒👍</div> </div>, <div class="comment-content"> <div class="comment_6953383843_6838793855 xe_content">정무감각 마이너스</div> </div>]
# 뭐 정치 감각 0인거 이미 영상으로 박제되어서 증명했잖아 노답임
# 도박 원툴 정치인
# 발레리안27지는 도박 전문이니 알등이 정치인이라 부르자
# 따다다동🍒👍
# 정무감각 마이너스
#
# https://www.fmkorea.com/6953350039 완료
# Title:  스토브리그에서 김종인이 보는 대권 주자들
# Time:  2024.04.23 11:08
# Post:  진행자가 몇 명보여주고 이야기함오세훈 - 꿈은 있다고 본다 서서히 준비하는 모습원희룡 - 원희룡도 꿈 있다고 보인다 하지만 이번 총선에서 상처 많이 입었다영웅심리가 있는건지 왜 힘든 곳으로 가서 떨어지면서 대권주자에서 다소 멀어졌다안철수 - 매 번 언급 되는 분이라서 딱히..... 본인이 의사인데 맨 처음에 목소리 내야했는데 선거 기간에 옳은 말 한 건 늦었다유승민 - 본인은 도전 할 수 있겠지만 잘 모르겠다이재명 - 특별한 일 아닌 이상 (사법리스크) 나온다 (대통령직 잘 할 것 같냐는 질문에) 그건 내가 판단할게 아니라 국민이 판단할 부분조국 - 상당히 힘들 것이다 (사법리스크 등)김동연 - 노무현 이후 경제 대통령으로 이명박이 된거 처럼 윤대통령시기 때 경제가 안 좋아지면 그런 식으로 나올 가능성이 있다
# []
#
# https://www.fmkorea.com/6953036291 완료
# Title:  오세훈 출생현황표 보면서 ㄹㅇ 문재앙 일자리현황표 떠올랐음ㅋㅋ
# Time:  2024.04.23 10:55
# Post:  https://n.news.naver.com/article/081/0003445991?sid=102
# []
#
# https://www.fmkorea.com/6953005051 완료
# Title:  [단독] 오세훈 서울시장실에 ‘출생아 상황판’ 설치한다
# Time:  2024.04.23 08:50
# Post:  https://n.news.naver.com/article/081/0003445991출생아 상황판은 시발아 ㅋㅋㅋㅋㅋㅋㅋ재앙이가 하던 짓이랑 다른 게 뭐임? ㅋㅋㅋㅋ이러다 나중엔 킁킁이처럼 서류뭉치도 쌓아놓고 살겠다
# [<div class="comment-content"> <div class="comment_6952761600_3645966663 xe_content">`오세훈이 죽으면 박원순이 마중나온다는 이야기를 나는 좋아한다` 이 댓글 생각나네 ㄷㄷ</div> </div>, <div class="comment-content"> <div class="comment_6952767883_6528066429 xe_content">오세훈 취임 하면서 제일 먼저 했던게 킁킁이가 설치한 서울시 상황판 철거였는데ㅋㅋㅋ</div> </div>, <div class="comment-content"> <div class="comment_6952774246_40309004 xe_content">성인 패스티벌 전기 끊는다고 협박하며</div> </div>, <div class="comment-content"> <div class="comment_6952859803_4122814889 xe_content">ㅅㅅ는 타부시하고...출생은 해야함</div> </div>, <div class="comment-content"> <div class="comment_6952866623_6319613083 xe_content">이건 무슨 냄새지 ㄷㄷ</div> </div>, <div class="comment-content"> <div class="comment_6952869524_6421629406 xe_content">저새끼 왜 갈수록 박원순 닮아가는거같냐</div> </div>, <div class="comment-content"> <div class="comment_6952874087_3669279084 xe_content">오좌빨</div> </div>, <div class="comment-content"> <div class="comment_6952878353_110042750 xe_content">당이랑 이름가리고 보면 서울시장이 민주당인줄 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ</div> </div>, <div class="comment-content"> <div class="comment_6952895999_4818166182 xe_content">5세 짓 다시 하네</div> </div>, <div class="comment-content"> <div class="comment_6952902140_2092431937 xe_content">벽에다가 낳아야한다 프린트해서 붙여놔라 ㅋㅋㅋㅋ</div> </div>, <div class="comment-content"> <div class="comment_6952905265_3201640793 xe_content">아..</div> </div>, <div class="comment-content"> <div class="comment_6952912165_3843255088 xe_content">오세훈 너는 이제 내마음속 차기대선후보에서 아웃이다.</div> </div>, <div class="comment-content"> <div class="comment_6952939658_44538285 xe_content">"낳아야 한다"</div> </div>, <div class="comment-content"> <div class="comment_6952969482_3736227256 xe_content">문짝 책상도 나오겠는데</div> </div>, <div class="comment-content"> <div class="comment_6952982261_6355880189 xe_content">진짜 어지간히 급한가보네ㅋㅋㅋㅋㅋ</div> </div>, <div class="comment-content"> <div class="comment_6953012184_2571101055 xe_content">AV보지말고 퐁퐁이 낳으라고 아ㅋㅋ</div> </div>, <div class="comment-content"> <div class="comment_6953016444_4801825328 xe_content">ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 존내 구태란 구태는 다하네 보여주식 세훈이 개추</div> </div>, <div class="comment-content"> <div class="comment_6953039311_2141329660 xe_content">오세훈 다음 대선 민주당에서 하는거 아니냐?</div> </div>, <div class="comment-content"> <div class="comment_6953098954_3800011168 xe_content">개씨발놈의 여자지원여자지원 애미씹창놈의새끼 ㅋㅋ</div> </div>, <div class="comment-content"> <div class="comment_6953175735_3253339153 xe_content">이런 씨발<br/>오세훈 거른다</div> </div>, <div class="comment-content"> <div class="comment_6953537685_3648482025 xe_content">쇼도 못하네 병신이<br/>저런 새끼가 어떻게 시장 당선된거냐<br/>아 준석이가 멱살잡고 끌어올렸지..</div> </div>, <div class="comment-content"> <div class="comment_6953624954_1315108307 xe_content">일자리 상황판 붙이던 누가 생각나눼요 훠훠훠</div> </div>, <div class="comment-content"> <div class="comment_6953659834_3901253199 xe_content">니 모니터로 보면 되지 상황판은 얼어죽을...</div> </div>, <div class="comment-content"> <div class="comment_6954050975_810510763 xe_content">훠재앙 따라하냐 ㅋㅋㅋ</div> </div>]
# `오세훈이 죽으면 박원순이 마중나온다는 이야기를 나는 좋아한다` 이 댓글 생각나네 ㄷㄷ
# 오세훈 취임 하면서 제일 먼저 했던게 킁킁이가 설치한 서울시 상황판 철거였는데ㅋㅋㅋ
# 성인 패스티벌 전기 끊는다고 협박하며
# ㅅㅅ는 타부시하고...출생은 해야함
# 이건 무슨 냄새지 ㄷㄷ
# 저새끼 왜 갈수록 박원순 닮아가는거같냐
# 오좌빨
# 당이랑 이름가리고 보면 서울시장이 민주당인줄 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
#